# %% [markdown]
# ### Load and pre-process the data

# %%
import re

with open('/kaggle/input/the-mysterious-island/The Mysterious Island.txt', 'r', encoding='utf-8') as f:
    text = f.read()

text = re.sub(r"[^a-zA-Z\s]", '', text)
text = re.sub(r'\s+', ' ', text).lower().strip()

# %%
len(text)
# Out:
# 1067356

# %% [markdown]
# ### Tokenization

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])
# Out:
# 2025-05-16 16:37:26.511193: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747413446.726967      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747413446.787381      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
word_index = tokenizer.word_index
vocab_size = len(word_index) + 1

# %%
print(f"Total unique words: {vocab_size}")
# Out:
# Total unique words: 10067

# %%
word_index
# Out:
# {'the': 1,
#  'of': 2,
#  'to': 3,
#  'and': 4,
#  'a': 5,
#  'was': 6,
#  'in': 7,
#  'it': 8,
#  'that': 9,
#  'which': 10,
#  'had': 11,
#  'not': 12,
#  'he': 13,
#  'they': 14,
#  'be': 15,
#  'on': 16,
#  'at': 17,
#  'his': 18,
#  'by': 19,
#  'this': 20,
#  'but': 21,
#  'as': 22,
#  'for': 23,
#  'with': 24,
#  'is': 25,
#  'were': 26,
#  'pencroft': 27,
#  'from': 28,
#  'would': 29,
#  'harding': 30,
#  'their': 31,
#  'have': 32,
#  'we': 33,
#  'been': 34,
#  'island': 35,
#  'no': 36,
#  'there': 37,
#  'could': 38,
#  'herbert': 39,
#  'all': 40,
#  'i': 41,
#  'cyrus': 42,
#  'said': 43,
#  'you': 44,
#  'them': 45,
#  'an': 46,
#  'him': 47,
#  'if': 48,
#  'will': 49,
#  'then': 50,
#  'engineer': 51,
#  'or': 52,
#  'some': 53,
#  'one': 54,
#  'so': 55,
#  'replied': 56,
#  'spilett': 57,
#  'neb': 58,
#  'who': 59,
#  'what': 60,
#  'these': 61,
#  'granite': 62,
#  'its': 63,
#  'more': 64,
#  'two': 65,
#  'are': 66,
#  'sailor': 67,
#  'time': 68,
#  'when': 69,
#  'house': 70,
#  'did': 71,
#  'now': 72,
#  'very': 73,
#  'into': 74,
#  'only': 75,
#  'any': 76,
#  'well': 77,
#  'reporter': 78,
#  'without': 79,
#  'must': 80,
#  'captain': 81,
#  'ayrton': 82,
#  'day': 83,
#  'my': 84,
#  'gideon': 85,
#  'than': 86,
#  'after': 87,
#  'first': 88,
#  'made': 89,
#  'up': 90,
#  'companions': 91,
#  'do': 92,
#  'might': 93,
#  'out': 94,
#  'colonists': 95,
#  'us': 96,
#  'our': 97,
#  'nothing': 98,
#  'sea': 99,
#  'water': 100,
#  'about': 101,
#  'before': 102,
#  'having': 103,
#  'should': 104,
#  'towards': 105,
#  'top': 106,
#  'asked': 107,
#  'other': 108,
#  'settlers': 109,
#  'found': 110,
#  'being': 111,
#  'even': 112,
#  'part': 113,
#  'soon': 114,
#  'great': 115,
#  'little': 116,
#  'corral': 117,
#  'shall': 118,
#  'has': 119,
#  'shore': 120,
#  'feet': 121,
#  'long': 122,
#  'appeared': 123,
#  'still': 124,
#  'few': 125,
#  'make': 126,
#  'during': 127,
#  'however': 128,
#  'over': 129,
#  'here': 130,
#  'himself': 131,
#  'vessel': 132,
#  'lincoln': 133,
#  'like': 134,
#  'left': 135,
#  'coast': 136,
#  'under': 137,
#  'again': 138,
#  'fire': 139,
#  'therefore': 140,
#  'may': 141,
#  'those': 142,
#  'where': 143,
#  'man': 144,
#  'themselves': 145,
#  'how': 146,
#  'also': 147,
#  'trees': 148,
#  'th': 149,
#  'cried': 150,
#  'three': 151,
#  'through': 152,
#  'way': 153,
#  'point': 154,
#  'work': 155,
#  'much': 156,
#  'miles': 157,
#  'already': 158,
#  'answered': 159,
#  'mercy': 160,
#  'necessary': 161,
#  'yet': 162,
#  'perhaps': 163,
#  'last': 164,
#  'her': 165,
#  'place': 166,
#  'say': 167,
#  'yes': 168,
#  'can': 169,
#  'good': 170,
#  'back': 171,
#  'returned': 172,
#  'wood': 173,
#  'such': 174,
#  'five': 175,
#  'new': 176,
#  'moment': 177,
#  'see': 178,
#  'rocks': 179,
#  'lake': 180,
#  'hundred': 181,
#  'think': 182,
#  'days': 183,
#  'know': 184,
#  'between': 185,
#  'since': 186,
#  'take': 187,
#  'most': 188,
#  'return': 189,
#  'among': 190,
#  'convicts': 191,
#  'night': 192,
#  'chimneys': 193,
#  'plateau': 194,
#  'passed': 195,
#  'seen': 196,
#  'off': 197,
#  'away': 198,
#  'several': 199,
#  'land': 200,
#  'come': 201,
#  'thus': 202,
#  'never': 203,
#  'find': 204,
#  'upon': 205,
#  'thought': 206,
#  'down': 207,
#  'go': 208,
#  'boat': 209,
#  'distance': 210,
#  'wind': 211,
#  'possible': 212,
#  'took': 213,
#  'light': 214,
#  'besides': 215,
#  'she': 216,
#  'less': 217,
#  'same': 218,
#  'large': 219,
#  'right': 220,
#  'balloon': 221,
#  'just': 222,
#  'me': 223,
#  'nor': 224,
#  'let': 225,
#  'mouth': 226,
#  'every': 227,
#  'hand': 228,
#  'observed': 229,
#  'hours': 230,
#  'forest': 231,
#  'remained': 232,
#  'far': 233,
#  'your': 234,
#  'beach': 235,
#  'river': 236,
#  'oclock': 237,
#  'able': 238,
#  'jup': 239,
#  'taken': 240,
#  'means': 241,
#  'ground': 242,
#  'least': 243,
#  'give': 244,
#  'while': 245,
#  'side': 246,
#  'either': 247,
#  'longer': 248,
#  'whose': 249,
#  'master': 250,
#  'animals': 251,
#  'above': 252,
#  'four': 253,
#  'men': 254,
#  'islet': 255,
#  'heard': 256,
#  'exclaimed': 257,
#  'against': 258,
#  'each': 259,
#  'set': 260,
#  'six': 261,
#  'fact': 262,
#  'done': 263,
#  'boy': 264,
#  'hour': 265,
#  'eyes': 266,
#  'too': 267,
#  'once': 268,
#  'next': 269,
#  'friends': 270,
#  'use': 271,
#  'near': 272,
#  'bonadventure': 273,
#  'brought': 274,
#  'doubt': 275,
#  'heights': 276,
#  'west': 277,
#  'formed': 278,
#  'alone': 279,
#  'height': 280,
#  'half': 281,
#  'name': 282,
#  'arrived': 283,
#  'everything': 284,
#  'indeed': 285,
#  'sand': 286,
#  'added': 287,
#  'put': 288,
#  'going': 289,
#  'life': 290,
#  'bank': 291,
#  'prospect': 292,
#  'many': 293,
#  'began': 294,
#  'rather': 295,
#  'leave': 296,
#  'always': 297,
#  'dog': 298,
#  'ready': 299,
#  'tabor': 300,
#  'reach': 301,
#  'minutes': 302,
#  'became': 303,
#  'enough': 304,
#  'went': 305,
#  'certainly': 306,
#  'almost': 307,
#  'another': 308,
#  'fell': 309,
#  'sort': 310,
#  'brig': 311,
#  'evening': 312,
#  'north': 313,
#  'question': 314,
#  'certain': 315,
#  'itself': 316,
#  'open': 317,
#  'high': 318,
#  'cold': 319,
#  'cape': 320,
#  'iron': 321,
#  'round': 322,
#  'covered': 323,
#  'course': 324,
#  'saw': 325,
#  'end': 326,
#  'why': 327,
#  'easily': 328,
#  'wished': 329,
#  'best': 330,
#  'rock': 331,
#  'thick': 332,
#  'came': 333,
#  'reached': 334,
#  'felt': 335,
#  'impossible': 336,
#  'knew': 337,
#  'creek': 338,
#  'south': 339,
#  'continued': 340,
#  'tide': 341,
#  'mountain': 342,
#  'air': 343,
#  'thrown': 344,
#  'passage': 345,
#  'evidently': 346,
#  'whom': 347,
#  'quite': 348,
#  'animal': 349,
#  'mount': 350,
#  'years': 351,
#  'difficult': 352,
#  'followed': 353,
#  'thousand': 354,
#  'immediately': 355,
#  'get': 356,
#  'hands': 357,
#  'sun': 358,
#  'fine': 359,
#  'chapter': 360,
#  'words': 361,
#  'pacific': 362,
#  'neither': 363,
#  'southern': 364,
#  'weather': 365,
#  'wild': 366,
#  'easy': 367,
#  'country': 368,
#  'carried': 369,
#  'although': 370,
#  'ran': 371,
#  'anything': 372,
#  'known': 373,
#  'hope': 374,
#  'morning': 375,
#  'horizon': 376,
#  'interior': 377,
#  'until': 378,
#  'franklin': 379,
#  'nearly': 380,
#  'foot': 381,
#  'till': 382,
#  'gave': 383,
#  'cliff': 384,
#  'often': 385,
#  'lava': 386,
#  'direction': 387,
#  'escaped': 388,
#  'others': 389,
#  'rose': 390,
#  'birds': 391,
#  'ever': 392,
#  'smoke': 393,
#  'ship': 394,
#  'making': 395,
#  'disappeared': 396,
#  'grant': 397,
#  'head': 398,
#  'better': 399,
#  'cart': 400,
#  'road': 401,
#  'mr': 402,
#  'become': 403,
#  'case': 404,
#  'placed': 405,
#  'care': 406,
#  'nemo': 407,
#  'both': 408,
#  'channel': 409,
#  'stream': 410,
#  'obliged': 411,
#  'coal': 412,
#  'pirates': 413,
#  'sight': 414,
#  'occupied': 415,
#  'wish': 416,
#  'presence': 417,
#  'state': 418,
#  'rate': 419,
#  'escape': 420,
#  'look': 421,
#  'along': 422,
#  'ten': 423,
#  'thing': 424,
#  'word': 425,
#  'am': 426,
#  'nature': 427,
#  'colony': 428,
#  'scarcely': 429,
#  'current': 430,
#  'short': 431,
#  'stranger': 432,
#  'lost': 433,
#  'bay': 434,
#  'shot': 435,
#  'opening': 436,
#  'doubtless': 437,
#  'waters': 438,
#  'chest': 439,
#  'months': 440,
#  'twenty': 441,
#  'second': 442,
#  'tools': 443,
#  'guns': 444,
#  'surface': 445,
#  'showed': 446,
#  'later': 447,
#  'important': 448,
#  'wait': 449,
#  'called': 450,
#  'want': 451,
#  'dwelling': 452,
#  'volcano': 453,
#  'board': 454,
#  'waves': 455,
#  'voyage': 456,
#  'month': 457,
#  'unknown': 458,
#  'stopped': 459,
#  'eight': 460,
#  'grass': 461,
#  'used': 462,
#  'raised': 463,
#  'matter': 464,
#  'agreed': 465,
#  'acid': 466,
#  'winter': 467,
#  'whole': 468,
#  'summit': 469,
#  'inhabited': 470,
#  'chance': 471,
#  'though': 472,
#  'bed': 473,
#  'things': 474,
#  'parts': 475,
#  'midst': 476,
#  'dark': 477,
#  'whether': 478,
#  'discovered': 479,
#  'sometimes': 480,
#  'lad': 481,
#  'branches': 482,
#  'exploration': 483,
#  'door': 484,
#  'rising': 485,
#  'taking': 486,
#  'ocean': 487,
#  'cut': 488,
#  'times': 489,
#  'suddenly': 490,
#  'port': 491,
#  'result': 492,
#  'given': 493,
#  'looked': 494,
#  'extreme': 495,
#  'length': 496,
#  'level': 497,
#  'probable': 498,
#  'lighted': 499,
#  'employed': 500,
#  'reason': 501,
#  'cavern': 502,
#  'lower': 503,
#  'danger': 504,
#  'appear': 505,
#  'engineers': 506,
#  'speak': 507,
#  'friend': 508,
#  'different': 509,
#  'reply': 510,
#  'narrow': 511,
#  'deep': 512,
#  'finished': 513,
#  'position': 514,
#  'rushed': 515,
#  'voice': 516,
#  'human': 517,
#  'enormous': 518,
#  'bottom': 519,
#  'try': 520,
#  'northern': 521,
#  'together': 522,
#  'operation': 523,
#  'terrible': 524,
#  'following': 525,
#  'rapidly': 526,
#  'seemed': 527,
#  'turn': 528,
#  'heat': 529,
#  'evident': 530,
#  'fear': 531,
#  'directly': 532,
#  'castaways': 533,
#  'strange': 534,
#  'incident': 535,
#  'feared': 536,
#  'order': 537,
#  'forward': 538,
#  'increased': 539,
#  'entered': 540,
#  'magnificent': 541,
#  'dont': 542,
#  'small': 543,
#  'believe': 544,
#  'complete': 545,
#  'sailors': 546,
#  'regular': 547,
#  'situation': 548,
#  'happened': 549,
#  'spot': 550,
#  'mile': 551,
#  'dead': 552,
#  'meanwhile': 553,
#  'difficulty': 554,
#  'low': 555,
#  'strong': 556,
#  'number': 557,
#  'help': 558,
#  'angle': 559,
#  'behind': 560,
#  'edge': 561,
#  'remain': 562,
#  'substance': 563,
#  'hunters': 564,
#  'game': 565,
#  'twelve': 566,
#  'ladder': 567,
#  'storm': 568,
#  'forests': 569,
#  'attempt': 570,
#  'pass': 571,
#  'poor': 572,
#  'rest': 573,
#  'gradually': 574,
#  'lay': 575,
#  'natural': 576,
#  'retreat': 577,
#  'advanced': 578,
#  'communication': 579,
#  'bridge': 580,
#  'does': 581,
#  'extended': 582,
#  'something': 583,
#  'power': 584,
#  'clear': 585,
#  'quickly': 586,
#  'perfectly': 587,
#  'soil': 588,
#  'exactly': 589,
#  'wall': 590,
#  'species': 591,
#  'sides': 592,
#  'future': 593,
#  'carefully': 594,
#  'fifty': 595,
#  'degrees': 596,
#  'duncan': 597,
#  'nautilus': 598,
#  'fresh': 599,
#  'fall': 600,
#  'seven': 601,
#  'keep': 602,
#  'red': 603,
#  'object': 604,
#  'idea': 605,
#  'saying': 606,
#  'bring': 607,
#  'dry': 608,
#  'east': 609,
#  'prepared': 610,
#  'crater': 611,
#  'canoe': 612,
#  'around': 613,
#  'sufficient': 614,
#  'struck': 615,
#  'black': 616,
#  'produced': 617,
#  'proceeded': 618,
#  'stones': 619,
#  'ended': 620,
#  'oh': 621,
#  'excellent': 622,
#  'obtained': 623,
#  'attack': 624,
#  'completely': 625,
#  'wire': 626,
#  'cannot': 627,
#  'march': 628,
#  'useful': 629,
#  'white': 630,
#  'apparatus': 631,
#  'true': 632,
#  'really': 633,
#  'numerous': 634,
#  'turned': 635,
#  'closed': 636,
#  'room': 637,
#  'consequently': 638,
#  'armed': 639,
#  'tell': 640,
#  'gulf': 641,
#  'because': 642,
#  'leaving': 643,
#  'claw': 644,
#  'cause': 645,
#  'beneath': 646,
#  'death': 647,
#  'gone': 648,
#  'within': 649,
#  'heart': 650,
#  'upper': 651,
#  'fallen': 652,
#  'led': 653,
#  'mind': 654,
#  'young': 655,
#  'broken': 656,
#  'extremity': 657,
#  'beyond': 658,
#  'probably': 659,
#  'sleep': 660,
#  'windows': 661,
#  'document': 662,
#  'lord': 663,
#  'world': 664,
#  'threw': 665,
#  'prevent': 666,
#  'understood': 667,
#  'considerable': 668,
#  'calm': 669,
#  'fixed': 670,
#  'simple': 671,
#  'search': 672,
#  'strength': 673,
#  'decided': 674,
#  'succeeded': 675,
#  'ourselves': 676,
#  'dear': 677,
#  'sail': 678,
#  'palisade': 679,
#  'possessed': 680,
#  'kept': 681,
#  'present': 682,
#  'instant': 683,
#  'powerful': 684,
#  'own': 685,
#  'examined': 686,
#  'extremely': 687,
#  'living': 688,
#  'refuge': 689,
#  'pencrofts': 690,
#  'sure': 691,
#  'distant': 692,
#  'received': 693,
#  'supplied': 694,
#  'herberts': 695,
#  'resumed': 696,
#  'eruption': 697,
#  'poultryyard': 698,
#  'heavy': 699,
#  'provisions': 700,
#  'close': 701,
#  'depths': 702,
#  'ought': 703,
#  'follow': 704,
#  'accustomed': 705,
#  'allowed': 706,
#  'disposal': 707,
#  'supposed': 708,
#  'spoke': 709,
#  'sky': 710,
#  'mass': 711,
#  'pieces': 712,
#  'opinion': 713,
#  'size': 714,
#  'situated': 715,
#  'latter': 716,
#  'immense': 717,
#  'old': 718,
#  'simply': 719,
#  'suppose': 720,
#  'powder': 721,
#  'wreck': 722,
#  'below': 723,
#  'year': 724,
#  'america': 725,
#  'traces': 726,
#  'unfortunate': 727,
#  'useless': 728,
#  'held': 729,
#  'serious': 730,
#  'body': 731,
#  'resolved': 732,
#  'darkness': 733,
#  'earth': 734,
#  'landed': 735,
#  'sharp': 736,
#  'attention': 737,
#  'opened': 738,
#  'season': 739,
#  'pole': 740,
#  'temperature': 741,
#  'tomorrow': 742,
#  'beasts': 743,
#  'bark': 744,
#  'western': 745,
#  'ayrtons': 746,
#  'october': 747,
#  'contrary': 748,
#  'vast': 749,
#  'contained': 750,
#  'thanks': 751,
#  'produce': 752,
#  'wounded': 753,
#  'met': 754,
#  'wanting': 755,
#  'occurred': 756,
#  'expedition': 757,
#  'separated': 758,
#  'bad': 759,
#  'mistaken': 760,
#  'trace': 761,
#  'ah': 762,
#  'latitude': 763,
#  'castaway': 764,
#  'april': 765,
#  'continent': 766,
#  'thirty': 767,
#  'speedy': 768,
#  'killed': 769,
#  'piece': 770,
#  'returning': 771,
#  'remarked': 772,
#  'carry': 773,
#  'tree': 774,
#  'cave': 775,
#  'discover': 776,
#  'dozen': 777,
#  'crossed': 778,
#  'inhabitants': 779,
#  'repeated': 780,
#  'saved': 781,
#  'entirely': 782,
#  'visit': 783,
#  'explosion': 784,
#  'glenarvan': 785,
#  'seized': 786,
#  'form': 787,
#  'single': 788,
#  'anchor': 789,
#  'furnished': 790,
#  'creature': 791,
#  'cross': 792,
#  'especially': 793,
#  'fired': 794,
#  'gun': 795,
#  'told': 796,
#  'cone': 797,
#  'allow': 798,
#  'influence': 799,
#  'manufacture': 800,
#  'plants': 801,
#  'deck': 802,
#  'mysterious': 803,
#  'cast': 804,
#  'traversed': 805,
#  'atmosphere': 806,
#  'arms': 807,
#  'barking': 808,
#  'union': 809,
#  'usual': 810,
#  'honest': 811,
#  'seeing': 812,
#  'event': 813,
#  'fastened': 814,
#  'plan': 815,
#  'dangerous': 816,
#  'rain': 817,
#  'blow': 818,
#  'composed': 819,
#  'descended': 820,
#  'rays': 821,
#  'attentively': 822,
#  'established': 823,
#  'spread': 824,
#  'quantity': 825,
#  'run': 826,
#  'surprised': 827,
#  'companion': 828,
#  'straight': 829,
#  'week': 830,
#  'bottle': 831,
#  'hull': 832,
#  'crew': 833,
#  'united': 834,
#  'ball': 835,
#  'vapor': 836,
#  'rapid': 837,
#  'richmond': 838,
#  'eye': 839,
#  'finding': 840,
#  'anxious': 841,
#  'arm': 842,
#  'account': 843,
#  'listened': 844,
#  'snow': 845,
#  'supply': 846,
#  'god': 847,
#  'border': 848,
#  'importance': 849,
#  'drew': 850,
#  'watch': 851,
#  'breakfast': 852,
#  'need': 853,
#  'approached': 854,
#  'drawn': 855,
#  'third': 856,
#  'november': 857,
#  'bob': 858,
#  'english': 859,
#  'turning': 860,
#  'notwithstanding': 861,
#  'southwest': 862,
#  'trouble': 863,
#  'recognized': 864,
#  'sheltered': 865,
#  'hemisphere': 866,
#  'live': 867,
#  'filled': 868,
#  'banks': 869,
#  'store': 870,
#  'peninsula': 871,
#  'approaching': 872,
#  'etc': 873,
#  'establish': 874,
#  'hoped': 875,
#  'hardings': 876,
#  'explored': 877,
#  'bows': 878,
#  'intended': 879,
#  'hear': 880,
#  'car': 881,
#  'beginning': 882,
#  'passing': 883,
#  'tried': 884,
#  'masters': 885,
#  'determined': 886,
#  'managed': 887,
#  'torn': 888,
#  'american': 889,
#  'fatigue': 890,
#  'uttered': 891,
#  'places': 892,
#  'band': 893,
#  'waited': 894,
#  'stood': 895,
#  'view': 896,
#  'walked': 897,
#  'rendered': 898,
#  'existed': 899,
#  'stretched': 900,
#  'coming': 901,
#  'exposed': 902,
#  'provided': 903,
#  'wound': 904,
#  'build': 905,
#  'period': 906,
#  'bullet': 907,
#  'fever': 908,
#  'nevertheless': 909,
#  'harvey': 910,
#  'noise': 911,
#  'northeast': 912,
#  'mingled': 913,
#  'departure': 914,
#  'articles': 915,
#  'throw': 916,
#  'breeze': 917,
#  'face': 918,
#  'lips': 919,
#  'struggle': 920,
#  'falls': 921,
#  'instead': 922,
#  'full': 923,
#  'intelligence': 924,
#  'wounds': 925,
#  'force': 926,
#  'guard': 927,
#  'running': 928,
#  'quarter': 929,
#  'volcanic': 930,
#  'clothes': 931,
#  'history': 932,
#  'condition': 933,
#  'shape': 934,
#  'render': 935,
#  'box': 936,
#  'effect': 937,
#  'grain': 938,
#  'explorers': 939,
#  'tops': 940,
#  'sent': 941,
#  'silent': 942,
#  'worked': 943,
#  'formerly': 944,
#  'glass': 945,
#  'onagers': 946,
#  'project': 947,
#  'solid': 948,
#  'forty': 949,
#  'minute': 950,
#  'save': 951,
#  'accompanied': 952,
#  'penetrate': 953,
#  'opportunity': 954,
#  'manufactured': 955,
#  'risk': 956,
#  'presented': 957,
#  'broke': 958,
#  'afterwards': 959,
#  'show': 960,
#  'silence': 961,
#  'nebs': 962,
#  'aspect': 963,
#  'belonged': 964,
#  'die': 965,
#  'food': 966,
#  'pointed': 967,
#  'eat': 968,
#  'green': 969,
#  'murmured': 970,
#  'arrival': 971,
#  'visited': 972,
#  'consequence': 973,
#  'surprise': 974,
#  'according': 975,
#  'ascended': 976,
#  'jacamar': 977,
#  'color': 978,
#  'inexplicable': 979,
#  'gazed': 980,
#  'greatly': 981,
#  'millions': 982,
#  'arranged': 983,
#  'talked': 984,
#  'knowing': 985,
#  'secret': 986,
#  'december': 987,
#  'yacht': 988,
#  'visible': 989,
#  'regions': 990,
#  'hold': 991,
#  'greatest': 992,
#  'plunged': 993,
#  'remains': 994,
#  'sudden': 995,
#  'prisoners': 996,
#  'vain': 997,
#  'perfect': 998,
#  'built': 999,
#  'rejoined': 1000,
#  ...}

# %% [markdown]
# ### Input Sequence Generation

# %%
from tensorflow.keras.utils import to_categorical
import numpy as np

input_sequences = []
token_list = tokenizer.texts_to_sequences([text])[0]

# %%
print(len(token_list))
# Out:
# 193276

# %%
token_list = token_list[:100000]

# %%
seq_length = 15

for i in range(seq_length ,len(token_list)):
    n_gram_sequence = token_list[i-seq_length: i+1]
    input_sequences.append(n_gram_sequence)

# %%
input_sequences = np.array(input_sequences)

# %%
X = input_sequences[:, :-1]
y = input_sequences[:, -1]
y = to_categorical(y, num_classes=vocab_size)

# %%
print("Data:", X[:1])
print("Response:", y[:1])
# Out:
# Data: [[   1  947 3696 2476    2    1  803   35   20 2476   25   23    1  271
#      2]]
# Response: [[0. 0. 0. ... 0. 0. 0.]]

# %%
print("X" , X.shape)
print("y" , y.shape)
# Out:
# X (99985, 15)
# y (99985, 10067)

# %%
len(y)
# Out:
# 99985

# %%
print(input_sequences)
# Out:
# [[   1  947 3696 ...  271    2 4505]
#  [ 947 3696 2476 ...    2 4505 3172]
#  [3696 2476    2 ... 4505 3172    7]
#  ...
#  [  45   22  114 ...  463    8    4]
#  [  22  114   22 ...    8    4  172]
#  [ 114   22   14 ...    4  172 5526]]

# %% [markdown]
# ### Model Building and Training

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=100))
model.add(LSTM(150, return_sequences=True))
model.add(LSTM(100))
model.add(Dense(vocab_size, activation='softmax'))

model.build(input_shape=(None, seq_length))
model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])
model.summary()
# Out:
# I0000 00:00:1747413489.841193      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 15, 100)             │       1,006,700 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 15, 150)             │         150,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 100)                 │         100,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 10067)               │       1,016,767 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,274,467 (8.68 MB)
#  Trainable params: 2,274,467 (8.68 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# from tensorflow.keras.models import load_model
# model = load_model('/kaggle/input/model_best2/keras/default/1/my_model_best_2.keras')

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='loss', patience=5)
model.fit(X, y, epochs=100, batch_size=64, callbacks=[early_stop])
# Out:
# Epoch 1/100
# I0000 00:00:1747413513.414331      91 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.0913 - loss: 6.7934
# Epoch 2/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.1142 - loss: 5.8972
# Epoch 3/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.1425 - loss: 5.5875
# Epoch 4/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.1561 - loss: 5.3851
# Epoch 5/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.1652 - loss: 5.2231
# Epoch 6/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.1695 - loss: 5.0890
# Epoch 7/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.1750 - loss: 4.9503
# Epoch 8/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.1824 - loss: 4.8099
# Epoch 9/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.1882 - loss: 4.6933
# Epoch 10/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.1918 - loss: 4.5964
# Epoch 11/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.1996 - loss: 4.4820
# Epoch 12/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.2042 - loss: 4.3849
# Epoch 13/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.2111 - loss: 4.2924
# Epoch 14/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.2151 - loss: 4.2161
# Epoch 15/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.2220 - loss: 4.1133
# Epoch 16/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.2267 - loss: 4.0405
# Epoch 17/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.2365 - loss: 3.9509
# Epoch 18/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.2433 - loss: 3.8819
# Epoch 19/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.2501 - loss: 3.8019
# Epoch 20/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.2599 - loss: 3.7224
# Epoch 21/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.2677 - loss: 3.6615
# Epoch 22/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.2779 - loss: 3.5879
# Epoch 23/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.2852 - loss: 3.5272
# Epoch 24/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.2936 - loss: 3.4683
# Epoch 25/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.3032 - loss: 3.4017
# Epoch 26/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.3100 - loss: 3.3484
# Epoch 27/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.3191 - loss: 3.2867
# Epoch 28/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.3266 - loss: 3.2227
# Epoch 29/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.3388 - loss: 3.1615
# Epoch 30/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.3468 - loss: 3.0998
# Epoch 31/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.3567 - loss: 3.0493
# Epoch 32/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.3646 - loss: 2.9886
# Epoch 33/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.3754 - loss: 2.9452
# Epoch 34/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.3838 - loss: 2.8836
# Epoch 35/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.3920 - loss: 2.8289
# Epoch 36/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.4028 - loss: 2.7712
# Epoch 37/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.4134 - loss: 2.7199
# Epoch 38/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.4214 - loss: 2.6685
# Epoch 39/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.4315 - loss: 2.6263
# Epoch 40/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.4416 - loss: 2.5643
# Epoch 41/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.4521 - loss: 2.5119
# Epoch 42/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.4614 - loss: 2.4578
# Epoch 43/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.4695 - loss: 2.4034
# Epoch 44/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.4812 - loss: 2.3571
# Epoch 45/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.4894 - loss: 2.3110
# Epoch 46/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.5019 - loss: 2.2614
# Epoch 47/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.5092 - loss: 2.2150
# Epoch 48/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.5211 - loss: 2.1656
# Epoch 49/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.5290 - loss: 2.1169
# Epoch 50/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.5353 - loss: 2.0827
# Epoch 51/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.5460 - loss: 2.0374
# Epoch 52/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.5549 - loss: 2.0012
# Epoch 53/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.5656 - loss: 1.9503
# Epoch 54/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.5752 - loss: 1.9071
# Epoch 55/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.5814 - loss: 1.8736
# Epoch 56/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.5937 - loss: 1.8227
# Epoch 57/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.6013 - loss: 1.7831
# Epoch 58/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.6062 - loss: 1.7568
# Epoch 59/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.6165 - loss: 1.7109
# Epoch 60/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.6274 - loss: 1.6780
# Epoch 61/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.6335 - loss: 1.6315
# Epoch 62/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.6424 - loss: 1.5991
# Epoch 63/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.6488 - loss: 1.5654
# Epoch 64/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.6550 - loss: 1.5388
# Epoch 65/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.6621 - loss: 1.5068
# Epoch 66/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.6723 - loss: 1.4722
# Epoch 67/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.6770 - loss: 1.4423
# Epoch 68/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.6850 - loss: 1.4115
# Epoch 69/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.6903 - loss: 1.3822
# Epoch 70/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.6998 - loss: 1.3500
# Epoch 71/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7030 - loss: 1.3268
# Epoch 72/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7098 - loss: 1.2977
# Epoch 73/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7180 - loss: 1.2563
# Epoch 74/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7212 - loss: 1.2391
# Epoch 75/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7294 - loss: 1.2064
# Epoch 76/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7335 - loss: 1.1920
# Epoch 77/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7387 - loss: 1.1720
# Epoch 78/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7468 - loss: 1.1406
# Epoch 79/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7525 - loss: 1.1124
# Epoch 80/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7551 - loss: 1.0938
# Epoch 81/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7601 - loss: 1.0733
# Epoch 82/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7656 - loss: 1.0550
# Epoch 83/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7716 - loss: 1.0359
# Epoch 84/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7750 - loss: 1.0149
# Epoch 85/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7771 - loss: 1.0074
# Epoch 86/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7842 - loss: 0.9763
# Epoch 87/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7883 - loss: 0.9543
# Epoch 88/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7904 - loss: 0.9400
# Epoch 89/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7952 - loss: 0.9269
# Epoch 90/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8008 - loss: 0.9011
# Epoch 91/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8043 - loss: 0.8862
# Epoch 92/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8055 - loss: 0.8748
# Epoch 93/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8122 - loss: 0.8522
# Epoch 94/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8109 - loss: 0.8485
# Epoch 95/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8163 - loss: 0.8320
# Epoch 96/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8182 - loss: 0.8170
# Epoch 97/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8234 - loss: 0.7995
# Epoch 98/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8261 - loss: 0.7802
# Epoch 99/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8311 - loss: 0.7662
# Epoch 100/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8345 - loss: 0.7529

# %%
early_stop = EarlyStopping(monitor='loss', patience=5)
model.fit(X, y, epochs=50, batch_size=64, callbacks=[early_stop])
# Out:
# Epoch 1/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8356 - loss: 0.7474
# Epoch 2/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8371 - loss: 0.7396
# Epoch 3/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8406 - loss: 0.7242
# Epoch 4/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8430 - loss: 0.7130
# Epoch 5/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8419 - loss: 0.7079
# Epoch 6/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8488 - loss: 0.6841
# Epoch 7/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8502 - loss: 0.6813
# Epoch 8/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8500 - loss: 0.6741
# Epoch 9/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8526 - loss: 0.6657
# Epoch 10/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8610 - loss: 0.6380
# Epoch 11/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8553 - loss: 0.6540
# Epoch 12/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8623 - loss: 0.6314
# Epoch 13/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8608 - loss: 0.6288
# Epoch 14/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8663 - loss: 0.6102
# Epoch 15/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8659 - loss: 0.6052
# Epoch 16/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8713 - loss: 0.5937
# Epoch 17/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8681 - loss: 0.5936
# Epoch 18/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8710 - loss: 0.5843
# Epoch 19/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8747 - loss: 0.5718
# Epoch 20/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8754 - loss: 0.5661
# Epoch 21/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8777 - loss: 0.5567
# Epoch 22/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8749 - loss: 0.5624
# Epoch 23/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8810 - loss: 0.5461
# Epoch 24/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8762 - loss: 0.5566
# Epoch 25/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8813 - loss: 0.5355
# Epoch 26/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8854 - loss: 0.5246
# Epoch 27/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8834 - loss: 0.5267
# Epoch 28/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8866 - loss: 0.5136
# Epoch 29/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8860 - loss: 0.5188
# Epoch 30/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8873 - loss: 0.5043
# Epoch 31/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8883 - loss: 0.5080
# Epoch 32/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8882 - loss: 0.5031
# Epoch 33/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8892 - loss: 0.4955
# Epoch 34/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8916 - loss: 0.4874
# Epoch 35/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8957 - loss: 0.4705
# Epoch 36/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8930 - loss: 0.4774
# Epoch 37/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8922 - loss: 0.4864
# Epoch 38/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8988 - loss: 0.4544
# Epoch 39/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8955 - loss: 0.4705
# Epoch 40/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.9005 - loss: 0.4588
# Epoch 41/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.9008 - loss: 0.4499
# Epoch 42/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8956 - loss: 0.4645
# Epoch 43/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8957 - loss: 0.4628
# Epoch 44/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8966 - loss: 0.4529
# Epoch 45/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.9025 - loss: 0.4363
# Epoch 46/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.9022 - loss: 0.4353
# Epoch 47/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.9036 - loss: 0.4307
# Epoch 48/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.9047 - loss: 0.4256
# Epoch 49/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.9016 - loss: 0.4366
# Epoch 50/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.9072 - loss: 0.4137

# %%
model.save('my_model_best_2.keras')

# %%
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

def generate_text(seed_text, next_words=50):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=seq_length, padding='pre')

        predicted_probs = model.predict(token_list, verbose=0)
        predicted_word_index = np.argmax(predicted_probs)

        output_word = tokenizer.index_word[predicted_word_index]
        seed_text += ' ' + output_word

    return seed_text

seed_text = "the"
generated_text = generate_text(seed_text, next_words=50)
print(generated_text)
# Out:
# the skill again disappeared on the beach below granite house could be who had been a good opportunity in collecting the water above the vast forest herbert and pencroft having cast him in the sea he would reach but had surveyed up the island if you must retrace this few minutes

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
from tensorflow.keras.models import load_model

model = load_model('/kaggle/input/model_best2/keras/default/1/my_model_best_2.keras')  
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Loss:{loss:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9167 - loss: 0.3847
# Test Accuracy: 0.9156
# Loss:0.3864
